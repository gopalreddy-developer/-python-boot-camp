# %%
#how to print values

print("30 days 30 hour challenge")
# Out:
# 30 days 30 hour challenge

# %%
#assigning string to vriables

name="gopal reddy"
days = "thirty days"
print(name)
print(days)
# Out:
# gopal reddy
# thirty days

# %%
#indexing string


s="gopal reddy"
print(s[0])
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[5])
print(s[6])
# Out:
# g
# o
# p
# a
# l
#
# r

# %%
#how to print pirticular character from given text

s="try hard get success"

print(s[4:8])
print(s[9:12])
print(s[13:20])
# Out:
# hard
# get
# success

# %%
#how to print length of given character

s="i will win"
name="gopal reddy"

print(len(s))
print(len(name))

#length includes space also
# Out:
# 10
# 11

# %%
#converting string into lower case
#converting string into uppercase

s="Try Hard Get Success"

print(s.lower())
print(s.upper())
# Out:
# try hard get success
# TRY HARD GET SUCCESS

# %%
#string concatination-joinin two strings

a="try again"
b="fail again"

print(a + b)
print(a+" "+b)#to add space between concatination
# Out:
# try againfail again
# try again fail again

# %%
#casefold()  usage

text="Thirty days and Thirty hours"

x=text.casefold()

print(x)
# Out:
# thirty days and thirty hours

# %%
#conerting cse fold with given values

s="DON'T TROUBLE THE TROUBLE UNTIL TROUBLE TROUBLES YOU"

print(s.capitalize()) #it converts only first leter into upper and other into lower

print(s.title())      #it converts first letter of every word in uppercase and remaing in lower case(title)

print(s.swapcase())   #it converts all upper case into lower and lower case into uppercase(swapcase)
# Out:
# Don't trouble the trouble until trouble troubles you
# Don'T Trouble The Trouble Until Trouble Troubles You
# don't trouble the trouble until trouble troubles you

# %%
#to check type of characters present in given string

s="DONT TROUBLE THE TROUBLE UNTIL TROUBLE TROUBLES YOU"

print(s.isalpha()) 

print(s.isalnum())

print(s.isdigit())

print(s.istitle())

print(s.isupper())

print(s.islower())

print(s.isspace())
# Out:
# False
# False
# False
# False
# True
# False
# False
