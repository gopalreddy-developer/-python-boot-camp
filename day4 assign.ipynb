# %%
# assinging value to a multiple variables

a= b= c = 100

print(a / 10)
print(b * 50)
print(c + 60)

# (//)floor divesion returns int value if both are int  or  if one valu is float returns floatvalue
print(a//20)
print(a//10.0)

# (**)power operator 

print(a**2)
# Out:
# 10.0
# 5000
# 160
# 5
# 10.0
# 10000

# %%
# replacing particular character 
s="goodle"
s1 = s.replace("d","g")
print(s1)


#replacing particular word
str = "hi hello how are you"

str1 = str.replace("how","who")
print(str1)
# Out:
# google
# goodle
# hi hello who are you

# %%
# typecasting converts one data type to other

a = 10
b =20.0

#to convert int to flot we have to use float() 
print(float(a))

#to convert float to flot we have to use int() 
print(int(b))

# to convert into boolen bool() (0 is False and non zero values True )
print(bool(a))

# to conver into complex type complex()  it is in the form of (a+bj)
print(complex(b))
# Out:
# 10.0
# 20
# True
# (20+0j)

# %%
# assigning multiple values
a,b,c = 10,20.0,"gopal"

# to multiple one must be string and other must be int
print(c * a)

# to concatinate both must be string
print(c + "3")
# Out:
# gopalgopalgopalgopalgopalgopalgopalgopalgopalgopal
# gopal3
